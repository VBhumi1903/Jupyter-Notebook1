# %% [markdown]
# # WEB API - Application Programming Interface

# %% [markdown]
# Making API request in python

# %%
#pip install request required

# %%
import pandas as pd
import numpy as np
import requests

# %%
response=requests.get("http://en.wikipedia.org/wiki/Data_science")

# %%
response.status_code
# Out:
# 200

# %%
response=requests.get("http://en.wikipedia.org/wiki/Data_science_does_not_exist")
response.status_code
# Out:
# 404

# %% [markdown]
# Status code:
#     200: Everything went okay, and the result has been returned if any
#
#    404: The souce you tried to access wasnt found on the server or not availabe for acces
#
#    https://github.com/dsrscientist/dataset1

# %%
df=pd.read_csv("employ.csv")

# %%
df
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df=pd.read_csv("employ.csv",index_col=['SNo'])

# %%
df
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
df.dtypes
# Out:
# Name        object
# Age        float64
# City        object
# Country     object
# Salary     float64
# dtype: object

# %%
df=pd.read_csv("employ.csv",dtype={'Salary':np.float64})

# %%
df.dtypes
# Out:
# SNo          int64
# Name        object
# Age        float64
# City        object
# Country     object
# Salary     float64
# dtype: object

# %%
df['Salary'].max()
# Out:
# 67666.0

# %%
df['Salary'].min()
# Out:
# 3900.0

# %%
df['Salary'].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df1=pd.DataFrame(data=df)

# %%
df1
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df1['Salary'].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df1.loc[:,'City']
# Out:
# 0       Toronto
# 1       Edmonto
# 2       Toronto
# 3      HongKong
# 4           NaN
# 5      HongKong
# 6       BayArea
# 7     Hyderabad
# 8       newyork
# 9       newyork
# 10     HongKong
# 11          NaN
# 12     HongKong
# 13          NaN
# 14    Hyderabad
# 15      newyork
# 16      newyork
# 17      Edmonto
# 18        Congo
# 19       Angola
# 20      Finland
# 21       London
# Name: City, dtype: object

# %%
df1.loc[:,['City','Country']]
# Out:
#          City  Country
# 0     Toronto   Canada
# 1     Edmonto   Canada
# 2     Toronto   Canada
# 3    HongKong     Asia
# 4         NaN  America
# 5    HongKong     Asia
# 6     BayArea  America
# 7   Hyderabad     Asia
# 8     newyork  America
# 9     newyork  America
# 10   HongKong     Asia
# 11        NaN  America
# 12   HongKong     Asia
# 13        NaN  America
# 14  Hyderabad     Asia
# 15    newyork  America
# 16    newyork  America
# 17    Edmonto   Canada
# 18      Congo   Africa
# 19     Angola   Africa
# 20    Finland   Europe
# 21     London   Europe

# %%
df.iloc[0:8,0:5]
# Out:
#    SNo    Name   Age       City  Country
# 0    1     Tom  28.0    Toronto   Canada
# 1    2     Lee  31.0    Edmonto   Canada
# 2    3    Dave  34.0    Toronto   Canada
# 3    4    Anik  26.0   HongKong     Asia
# 4    5   kamal  30.0        NaN  America
# 5    6    Geet   NaN   HongKong     Asia
# 6    7  Steven  43.0    BayArea  America
# 7    8     Ram  38.0  Hyderabad     Asia

# %%
#how many rows are present there  ------> doesnt count NaN data (missing data)
df.count()
# Out:
# SNo        22
# Name       22
# Age        19
# City       19
# Country    22
# Salary     19
# dtype: int64

# %%
df['Name'].count()
# Out:
# 22

# %%
df['Age'].count()
# Out:
# 19

# %%
df['Name'].unique()   # unique names will displayed .. not repeated
# Out:
# array(['Tom', 'Lee', 'Dave', 'Anik', 'kamal', 'Geet', 'Steven', 'Ram',
#        'hari', 'yami', 'Andrew', 'soham', 'Grig', 'Kiara'], dtype=object)

# %%
df['Name'].nunique()  #nunique gives you number of count of unique value
# Out:
# 14

# %%
df['Name'].describe()
# Out:
# count      22
# unique     14
# top       Lee
# freq        2
# Name: Name, dtype: object

# %%
df.describe()  # gives you statstical data report
# Out:
#              SNo        Age        Salary
# count  22.000000  19.000000     19.000000
# mean   12.090909  32.421053  33739.947368
# std     6.927578   7.174924  23151.188084
# min     1.000000  22.000000   3900.000000
# 25%     6.250000  27.000000   8888.000000
# 50%    12.500000  31.000000  33451.000000
# 75%    17.750000  36.000000  54666.000000
# max    23.000000  50.000000  67666.000000

# %%
df.count()
# Out:
# SNo        22
# Name       22
# Age        19
# City       19
# Country    22
# Salary     19
# dtype: int64

# %% [markdown]
# # so we will use describe() function only for numeric data

# %%
df.describe(include='all') # will include all date includeing numeric,string,float,missing value
# Out:
#               SNo Name        Age      City  Country        Salary
# count   22.000000   22  19.000000        19       22     19.000000
# unique        NaN   14        NaN        10        5           NaN
# top           NaN  Lee        NaN  HongKong  America           NaN
# freq          NaN    2        NaN         4        8           NaN
# mean    12.090909  NaN  32.421053       NaN      NaN  33739.947368
# std      6.927578  NaN   7.174924       NaN      NaN  23151.188084
# min      1.000000  NaN  22.000000       NaN      NaN   3900.000000
# 25%      6.250000  NaN  27.000000       NaN      NaN   8888.000000
# 50%     12.500000  NaN  31.000000       NaN      NaN  33451.000000
# 75%     17.750000  NaN  36.000000       NaN      NaN  54666.000000
# max     23.000000  NaN  50.000000       NaN      NaN  67666.000000

# %% [markdown]
# Droping any row or column

# %%
dp=df.drop([7,8,9],axis=0)  #axis means rows

# %%
dp  #changes are only done temporary, original table has still data availbale
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# 17   19     Lee  31.0    Edmonto   Canada      NaN
# 18   20  Andrew  34.0      Congo   Africa  34432.0
# 19   21   soham  32.0     Angola   Africa  34534.0
# ...

# %%
df
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
#drop the data in the original table
df.drop([7,8],axis=0,inplace=True)

# %%
df
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# 17   19     Lee  31.0    Edmonto   Canada      NaN
# 18   20  Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
df.drop(['City'],axis=1,inplace=True)

# %%
df
# Out:
#     SNo    Name   Age  Country   Salary
# 0     1     Tom  28.0   Canada  20000.0
# 1     2     Lee  31.0   Canada   3900.0
# 2     3    Dave  34.0   Canada   8000.0
# 3     4    Anik  26.0     Asia  66672.0
# 4     5   kamal  30.0  America      NaN
# 5     6    Geet   NaN     Asia  30007.0
# 6     7  Steven  43.0  America   8300.0
# 9    11    yami   NaN  America   8888.0
# 10   12    Anik  26.0     Asia  66672.0
# 11   13   kamal  30.0  America  34344.0
# 12   14    Geet  22.0     Asia  30007.0
# 13   15  Steven  43.0  America   8300.0
# 14   16     Ram  38.0     Asia  54666.0
# 15   17    hari   NaN  America  67666.0
# 16   18    yami  27.0  America   8888.0
# 17   19     Lee  31.0   Canada      NaN
# 18   20  Andrew  34.0   Africa  34432.0
# 19   21   soham  32.0   Africa  34534.0
# 20   22    Grig  26.0   Europe  33451.0
# 21   23   Kiara  27.0   Europe      NaN

# %%
df.dropna(axis=0)  #drop all the value along with rows
# Out:
#     SNo    Name   Age  Country   Salary
# 0     1     Tom  28.0   Canada  20000.0
# 1     2     Lee  31.0   Canada   3900.0
# 2     3    Dave  34.0   Canada   8000.0
# 3     4    Anik  26.0     Asia  66672.0
# 6     7  Steven  43.0  America   8300.0
# 10   12    Anik  26.0     Asia  66672.0
# 11   13   kamal  30.0  America  34344.0
# 12   14    Geet  22.0     Asia  30007.0
# 13   15  Steven  43.0  America   8300.0
# 14   16     Ram  38.0     Asia  54666.0
# 16   18    yami  27.0  America   8888.0
# 18   20  Andrew  34.0   Africa  34432.0
# 19   21   soham  32.0   Africa  34534.0
# 20   22    Grig  26.0   Europe  33451.0

# %%
df.describe()
# Out:
#           SNo        Age        Salary
# count  20.000  17.000000     17.000000
# mean   12.450  31.058824  30513.352941
# std     7.178   5.889297  22194.781132
# min     1.000  22.000000   3900.000000
# 25%     5.750  27.000000   8888.000000
# 50%    13.500  30.000000  30007.000000
# 75%    18.250  34.000000  34534.000000
# max    23.000  43.000000  67666.000000

# %%
df.count()
# Out:
# SNo        20
# Name       20
# Age        17
# Country    20
# Salary     17
# dtype: int64

# %%
data=pd.read_csv("employ.csv",index_col=0)
data.to_excel("employ.xlsx")

# %%
data
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
data
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %% [markdown]
# # Pandas Date Time Functions

# %%
import pandas as pd

# %%
df=pd.read_csv("hrdata.csv")
df
# Out:
#              Name  HireDate   Salary  SickDaysremaining
# 0  Graham Chapman  03/15/14  50000.0                 10
# 1     John Cleese  06/01/15  65000.0                  8
# 2       Eric Idle  05/12/14  45000.0                 10
# 3     Terry Jones  11/01/13  70000.0                  3
# 4   Terry Gilliam  08/12/14  48000.0                  7
# 5   Michael Palin  05/23/13  66000.0                  8

# %%
d=pd.to_datetime({'year':[2023],'month':[3],'day':[5]})
d
# Out:
# 0   2023-03-05
# dtype: datetime64[ns]

# %%
df['HireDate']=pd.to_datetime(df['HireDate'])
df
# Out:
#              Name   HireDate   Salary  SickDaysremaining
# 0  Graham Chapman 2014-03-15  50000.0                 10
# 1     John Cleese 2015-06-01  65000.0                  8
# 2       Eric Idle 2014-05-12  45000.0                 10
# 3     Terry Jones 2013-11-01  70000.0                  3
# 4   Terry Gilliam 2014-08-12  48000.0                  7
# 5   Michael Palin 2013-05-23  66000.0                  8

# %% [markdown]
# date_range function is avaialbe in pandas

# %%
daterange=pd.date_range(start='1/15/2020',end='02/10/2020',freq="D")
daterange
# Out:
# DatetimeIndex(['2020-01-15', '2020-01-16', '2020-01-17', '2020-01-18',
#                '2020-01-19', '2020-01-20', '2020-01-21', '2020-01-22',
#                '2020-01-23', '2020-01-24', '2020-01-25', '2020-01-26',
#                '2020-01-27', '2020-01-28', '2020-01-29', '2020-01-30',
#                '2020-01-31', '2020-02-01', '2020-02-02', '2020-02-03',
#                '2020-02-04', '2020-02-05', '2020-02-06', '2020-02-07',
#                '2020-02-08', '2020-02-09', '2020-02-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
daterange=pd.date_range(start='1/1/2020',end='1/1/2021',freq="M")
daterange
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30',
#                '2020-05-31', '2020-06-30', '2020-07-31', '2020-08-31',
#                '2020-09-30', '2020-10-31', '2020-11-30', '2020-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
pd.to_timedelta?

# %%
import datetime

# %%
dt=datetime.datetime.now()    #printing current date and time
print(dt)
# Out:
# 2023-08-24 17:43:05.179792

# %%
 # timedelta Respresents a duration, the difference between two dates or times
print(dt+pd.to_timedelta(20,unit='D'))
# Out:
# 2023-09-13 17:43:05.179792

# %%
df['Day']=df['HireDate'].dt.day
df['Month']=df['HireDate'].dt.month
df['Year']=df['HireDate'].dt.year
print(df)
# Out:
#              Name   HireDate   Salary  SickDaysremaining  Day  Month  Year
# 0  Graham Chapman 2014-03-15  50000.0                 10   15      3  2014
# 1     John Cleese 2015-06-01  65000.0                  8    1      6  2015
# 2       Eric Idle 2014-05-12  45000.0                 10   12      5  2014
# 3     Terry Jones 2013-11-01  70000.0                  3    1     11  2013
# 4   Terry Gilliam 2014-08-12  48000.0                  7   12      8  2014
# 5   Michael Palin 2013-05-23  66000.0                  8   23      5  2013
